# %% [markdown]
# ## Scraping a dedicated page : Under the Queen's Umbrela

# %% [markdown]
# ## Setting up the get request

# %%
##setting up a get request 

import requests
import time 
import re 
from bs4 import BeautifulSoup 

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
}
URL= "https://mydramalist.com/705857-umbrella/reviews"
page = requests.get(URL, headers=headers, timeout=10)
page.raise_for_status()  
#Checking status code 
print(page.status_code)
print(page.text[:500])
# Out:
# 200
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <title>Under the Queen's Umbrella Reviews - MyDramaList</title>
# <link rel="dns-prefetch" href="//fonts.gstatic.com">
# <link rel="dns-prefetch" href="//fonts.googleapis.com">
# <link rel="dns-prefetch" href="//apis.google.com">
# <link rel="dns-prefetch" href="//tpc.googlesyndication.com">
# <link rel="dns-prefetch" href="//googleads.g.doubleclick.net">
# <link rel="dns-prefetch" href="//securepubads.g.doubleclick.net">
# <link rel="preconnect" href="//fonts.gstati

# %%
#getting each review 
def get_reviews(response):
    soup = BeautifulSoup(response.text, "html.parser")
    shows = []
    container_class = "review"

    containers = soup.find_all("div", class_=container_class)
    print(f"Found {len(containers)} show containers using class '{container_class}'")

    for item in containers:
        name_wrapper = item.find(class_="review")
        name_tag = name_wrapper.find("a") if name_wrapper else None
      
        info_tag = item.find(class_="text-muted")

        title = title_tag.text.strip() if title_tag else None
        url = title_tag["href"] if title_tag and title_tag.has_attr("href") else None
        info = info_tag.text.strip() if info_tag else None
        episodes = None
        #extracting number of episodes 
        if info:
            match = re.search(r"(\d+)\s+episodes?", info)
            if match:
                episodes = int(match.group(1))

        shows.append({
            "title": title,
            "url": url,
            "info": info,
            "episodes": episodes,
        })

    return shows
